# %%
##EDA on Cardiographic Dataset
##import libraries and load data
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv("cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
##check data info and clean it
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#               LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  \
# 1     132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1
# 59    144.000000  0.008143  0.0  0.006595  0.000000  0.0  0.0  33.0   1.1
# 62    142.000000  0.000000  0.0  0.003311  0.000000  0.0  0.0  25.0   1.3
# 63    136.000000  0.002513  0.0  0.005025  0.000000  0.0  0.0  24.0   1.5
# ...          ...       ...  ...       ...       ...  ...  ...   ...   ...
# 1989  135.000000  0.006427  0.0  0.003856  0.000000  0.0  0.0  58.0   1.0
# 1990  134.878101  0.006127  0.0  0.001225  0.000000  0.0  0.0  58.0   1.1
# 1992  135.000000  0.007798  0.0  0.005240  0.000000  0.0  0.0  58.0   1.0
# 2078  130.000000  0.004789  0.0  0.000958  0.000000  0.0  0.0  73.0   0.6
# 2079  130.000000  0.003525  0.0  0.001175  0.000026  0.0  0.0  75.0   0.6
#
#            ALTV  MLTV       Width  Tendency  NSP
# ...

# %%
df=df.fillna(df.mean())

# %%
df
# Out:
#               LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  \
# 1     132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1
# 59    144.000000  0.008143  0.0  0.006595  0.000000  0.0  0.0  33.0   1.1
# 62    142.000000  0.000000  0.0  0.003311  0.000000  0.0  0.0  25.0   1.3
# 63    136.000000  0.002513  0.0  0.005025  0.000000  0.0  0.0  24.0   1.5
# ...          ...       ...  ...       ...       ...  ...  ...   ...   ...
# 1989  135.000000  0.006427  0.0  0.003856  0.000000  0.0  0.0  58.0   1.0
# 1990  134.878101  0.006127  0.0  0.001225  0.000000  0.0  0.0  58.0   1.1
# 1992  135.000000  0.007798  0.0  0.005240  0.000000  0.0  0.0  58.0   1.0
# 2078  130.000000  0.004789  0.0  0.000958  0.000000  0.0  0.0  73.0   0.6
# 2079  130.000000  0.003525  0.0  0.001175  0.000026  0.0  0.0  75.0   0.6
#
#            ALTV  MLTV       Width  Tendency  NSP
# ...

# %%
##Detect and handle outliers using IQR
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
df.describe()
# Out:
#                LB          AC     FM          UC          DL     DS     DP  \
# count  317.000000  317.000000  317.0  317.000000  317.000000  317.0  317.0
# mean   131.173782    0.003091    0.0    0.004831    0.000725    0.0    0.0
# std      9.604908    0.002602    0.0    0.002254    0.001242    0.0    0.0
# min    106.000000   -0.000117    0.0    0.000000   -0.000080    0.0    0.0
# 25%    122.097004    0.000000    0.0    0.003361    0.000000    0.0    0.0
# 50%    132.000000    0.002778    0.0    0.005080    0.000000    0.0    0.0
# 75%    139.000000    0.005190    0.0    0.006567    0.001014    0.0    0.0
# max    146.000000    0.008325    0.0    0.008696    0.004283    0.0    0.0
#
#              ASTV        MSTV        ALTV        MLTV       Width    Tendency  \
# count  317.000000  317.000000  317.000000  317.000000  317.000000  317.000000
# mean    38.603886    1.077429    2.313986    9.225186   54.358206    0.233178
# ...

# %%
##show summary statistics
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
##visualize the data
##histogram
import matplotlib.pyplot as plt
df.hist(figsize=(12,8),bins=15)
plt.tight_layout()
plt.show()

# %%
##Boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title("Boxplot of all features")
plt.show()

# %%
##correlation Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
##Violin plot example
plt.figure(figsize=(10,6))
sns.violinplot(data=df[['LB','AC','FM']])
plt.title("Violin plots of LB,AC and FM")
plt.show()

# %%
##pattern recognition and insights
##Identify top correlations
correlation_matrix=df.corr()
strong_corr=correlation_matrix[(correlation_matrix>0.5)&(correlation_matrix>0.1)]
print(strong_corr.dropna(how='all').dropna(axis=1,how='all'))
sns.scatterplot(x='LB',y='AC',data=df)
plt.title("LB VS AC")
plt.show()
# Out:
#            LB   AC   UC        DL  ASTV  MSTV  ALTV  MLTV     Width  Tendency
# LB        1.0  NaN  NaN       NaN   NaN   NaN   NaN   NaN       NaN       NaN
# AC        NaN  1.0  NaN       NaN   NaN   NaN   NaN   NaN       NaN       NaN
# UC        NaN  NaN  1.0       NaN   NaN   NaN   NaN   NaN       NaN       NaN
# DL        NaN  NaN  NaN  1.000000   NaN   NaN   NaN   NaN  0.506142       NaN
# ASTV      NaN  NaN  NaN       NaN   1.0   NaN   NaN   NaN       NaN       NaN
# MSTV      NaN  NaN  NaN       NaN   NaN   1.0   NaN   NaN       NaN       NaN
# ALTV      NaN  NaN  NaN       NaN   NaN   NaN   1.0   NaN       NaN       NaN
# MLTV      NaN  NaN  NaN       NaN   NaN   NaN   NaN   1.0       NaN       NaN
# Width     NaN  NaN  NaN  0.506142   NaN   NaN   NaN   NaN  1.000000       NaN
# Tendency  NaN  NaN  NaN       NaN   NaN   NaN   NaN   NaN       NaN       1.0

# %%
##Conclusion and Recommendations
Key Findings:

The dataset is clean with no major missing values after preprocessing.

LB, AC, and UC are key indicators of fetal well-being.

Variability indicators like ASTV, ALTV help assess fetal health variability.

Outliers were present in a few deceleration measures and were removed using IQR.

Recommendations:
Use LB, AC, and ASTV as input features for potential classification models.

Consider further medical interpretation before making decisions.

Explore clustering or classification (e.g., healthy vs. distressed) in future analysis.
